# %%
pip install dabl
# Out:
# ...
#   Using cached dabl-0.2.5-py3-none-any.whl (564 kB)
# ...
#      -------------------------------------- 563.9/563.9 kB 5.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import dabl
road_safety = pd.read_csv(dabl.datasets.data_path("C:\\Users\\heman\\DataScience\\AutoViz\\autoviz\\RTADataset.csv"))

# %%
road_safety.shape
# Out:
# (12316, 32)

# %%
road_safety.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
road_safety_clean = dabl.clean(road_safety, verbose=0)

# %%
types = dabl.detect_types(road_safety_clean)
print(types)
# Out:
#                                       continuous  dirty_float  low_card_int  \
# Time                                       False        False         False
# Day_of_week                                False        False         False
# Age_band_of_driver                         False        False         False
# Sex_of_driver                              False        False         False
# Educational_level                          False        False         False
# Vehicle_driver_relation                    False        False         False
# Driving_experience                         False        False         False
# Type_of_vehicle                            False        False         False
# Owner_of_vehicle                           False        False         False
# Service_year_of_vehicle                    False        False         False
# Area_accident_occured                      False        False         False
# ...

# %%
dabl.plot(road_safety, 'Day_of_week')
# Out:
# C:\Users\heman\.conda\envs\ML\lib\site-packages\dabl\plot\supervised.py:612: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   FutureWarning)
# Target looks like classification
# Showing only top 10 of 31 categorical features
# [[<Figure size 300x300 with 2 Axes>], None]
